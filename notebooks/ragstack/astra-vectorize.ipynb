# %% [markdown]
# Start with installing ragstack-ai module

# %%
# !pip3 install ragstack-ai
# Out:
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# Collecting ragstack-ai
#   Obtaining dependency information for ragstack-ai from https://files.pythonhosted.org/packages/7a/6d/62f40b9b51daa0ce481aa77d77922576ec2e7ed5fa12c8b2d0ab2e0b3388/ragstack_ai-0.1.0-py3-none-any.whl.metadata
#   Downloading ragstack_ai-0.1.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting PyYAML>=5.3 (from ragstack-ai)
#   Obtaining dependency information for PyYAML>=5.3 from https://files.pythonhosted.org/packages/ec/0d/26fb23e8863e0aeaac0c64e03fd27367ad2ae3f3cccf3798ee98ce160368/PyYAML-6.0.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading PyYAML-6.0.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from ragstack-ai)
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/be/67/7c054e93e1cca2d04ed69548ebf21134ace9c74efd008f936aa371a001be/SQLAlchemy-2.0.23-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading SQLAlchemy-2.0.23-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from ragstack-ai)
#   Obtaining dependency information for aiohttp<4.0.0,>=3.8.3 from https://files.pythonhosted.org/packages/0b/f7/6fce2fa9c9352c2b0a9868cbd6aaab57a46fa52330e90c0fa0cdf990cec0/aiohttp-3.8.6-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading aiohttp-3.8.6-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.7 kB)
# Collecting anyio<4.0 (from ragstack-ai)
#   Obtaining dependency information for anyio<4.0 from https://files.pythonhosted.org/packages/19/24/44299477fe7dcc9cb58d0a57d5a7588d6af2ff403fdd2d47a246c91a3246/anyio-3.7.1-py3-none-any.whl.metadata
#   Downloading anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting astrapy==0.5.8 (from ragstack-ai)
#   Obtaining dependency information for astrapy==0.5.8 from https://files.pythonhosted.org/packages/6b/36/199af56c0b49f680b37b89511bed27a7cc68feeebe36fdc5887d55845925/astrapy-0.5.8-py3-none-any.whl.metadata
#   Downloading astrapy-0.5.8-py3-none-any.whl.metadata (11 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from ragstack-ai)
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/8d/e2/528c52001a743a7faa28e6d3095d9f01b472d3efee62d62101403bf1a70a/dataclasses_json-0.6.2-py3-none-any.whl.metadata
#   Downloading dataclasses_json-0.6.2-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from ragstack-ai)
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting numpy<2,>=1 (from ragstack-ai)
#   Obtaining dependency information for numpy<2,>=1 from https://files.pythonhosted.org/packages/51/3b/2ba379bf754f13041e3d8b994394e78c69cdb9d1e5dd1dba9404b24afbdf/numpy-1.26.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading numpy-1.26.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 785.2 kB/s eta 0:00:00 0:00:01
# Collecting openai<1,>=0 (from ragstack-ai)
#   Obtaining dependency information for openai<1,>=0 from https://files.pythonhosted.org/packages/1e/9f/385c25502f437686e4aa715969e5eaf5c2cb5e5ffa7c5cdd52f3c6ae967a/openai-0.28.1-py3-none-any.whl.metadata
#   Downloading openai-0.28.1-py3-none-any.whl.metadata (11 kB)
# Collecting pydantic<3,>=1 (from ragstack-ai)
#   Obtaining dependency information for pydantic<3,>=1 from https://files.pythonhosted.org/packages/e2/2c/9906b7abc337b0250a5634de5396e2f3cb1b837af0616424c2225a65aa80/pydantic-2.5.1-py3-none-any.whl.metadata
#   Downloading pydantic-2.5.1-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.1/64.1 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting pytest-subtests<0.12.0,>=0.11.0 (from ragstack-ai)
#   Obtaining dependency information for pytest-subtests<0.12.0,>=0.11.0 from https://files.pythonhosted.org/packages/8a/98/50ac2d1344b0c43b81f886171e5ecf51a27fd02b32f787862f76fd7779dc/pytest_subtests-0.11.0-py3-none-any.whl.metadata
#   Downloading pytest_subtests-0.11.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting requests<3,>=2 (from ragstack-ai)
#   Obtaining dependency information for requests<3,>=2 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from ragstack-ai)
#   Obtaining dependency information for tenacity<9.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting tiktoken<0.6.0,>=0.3.2 (from ragstack-ai)
#   Obtaining dependency information for tiktoken<0.6.0,>=0.3.2 from https://files.pythonhosted.org/packages/15/02/f0d7c68ed90594d90891ee13b87d621ffc3434cccbc461d1f72086ebf0e1/tiktoken-0.5.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading tiktoken-0.5.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting faker~=19.11.0 (from astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for faker~=19.11.0 from https://files.pythonhosted.org/packages/65/f5/3a25d3775030fc717720072d2fb1aabf90ae3f39851e860bc6cc4580188f/Faker-19.11.1-py3-none-any.whl.metadata
#   Downloading Faker-19.11.1-py3-none-any.whl.metadata (15 kB)
# Collecting pytest~=7.4.2 (from astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for pytest~=7.4.2 from https://files.pythonhosted.org/packages/f3/8c/f16efd81ca8e293b2cc78f111190a79ee539d0d5d36ccd49975cb3beac60/pytest-7.4.3-py3-none-any.whl.metadata
#   Downloading pytest-7.4.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting pytest-cov~=4.1.0 (from astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for pytest-cov~=4.1.0 from https://files.pythonhosted.org/packages/a7/4b/8b78d126e275efa2379b1c2e09dc52cf70df16fc3b90613ef82531499d73/pytest_cov-4.1.0-py3-none-any.whl.metadata
#   Downloading pytest_cov-4.1.0-py3-none-any.whl.metadata (26 kB)
# Collecting pytest-testdox~=3.1.0 (from astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for pytest-testdox~=3.1.0 from https://files.pythonhosted.org/packages/94/8c/515ff4ab03b744b00f1283455ff189537082a16f62aa5ace6171f4cb5aea/pytest_testdox-3.1.0-py2.py3-none-any.whl.metadata
#   Downloading pytest_testdox-3.1.0-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting requests-toolbelt~=1.0.0 (from astrapy==0.5.8->ragstack-ai)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting python-dotenv~=1.0.0 (from astrapy==0.5.8->ragstack-ai)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting pre-commit~=3.5.0 (from astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for pre-commit~=3.5.0 from https://files.pythonhosted.org/packages/6c/75/526915fedf462e05eeb1c75ceaf7e3f9cde7b5ce6f62740fe5f7f19a0050/pre_commit-3.5.0-py2.py3-none-any.whl.metadata
#   Downloading pre_commit-3.5.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting cassio~=0.1.3 (from astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for cassio~=0.1.3 from https://files.pythonhosted.org/packages/3e/5a/ffa637f450a1544ba2c15f6377c79ed26de50be18e67758001e5db760ea3/cassio-0.1.3-py3-none-any.whl.metadata
#   Downloading cassio-0.1.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->ragstack-ai)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4.0,>=2.0 (from aiohttp<4.0.0,>=3.8.3->ragstack-ai)
#   Obtaining dependency information for charset-normalizer<4.0,>=2.0 from https://files.pythonhosted.org/packages/3e/33/21a875a61057165e92227466e54ee076b73af1e21fe1b31f1e292251aa1e/charset_normalizer-3.3.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (33 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->ragstack-ai)
#   Using cached multidict-6.0.4-cp311-cp311-macosx_10_9_x86_64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp<4.0.0,>=3.8.3->ragstack-ai)
#   Obtaining dependency information for async-timeout<5.0,>=4.0.0a3 from https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl.metadata
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->ragstack-ai)
#   Using cached yarl-1.9.2-cp311-cp311-macosx_10_9_x86_64.whl (64 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->ragstack-ai)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/1d/29/1a30aedecf5b6542f1dba92383352ccb35a3affcdf94bc5b2917dc95ce3b/frozenlist-1.4.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading frozenlist-1.4.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->ragstack-ai)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting idna>=2.8 (from anyio<4.0->ragstack-ai)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting sniffio>=1.1 (from anyio<4.0->ragstack-ai)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->ragstack-ai)
#   Obtaining dependency information for marshmallow<4.0.0,>=3.18.0 from https://files.pythonhosted.org/packages/ed/3c/cebfdcad015240014ff08b883d1c0c427f2ba45ae8c6572851b6ef136cad/marshmallow-3.20.1-py3-none-any.whl.metadata
#   Downloading marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->ragstack-ai)
#   Obtaining dependency information for typing-inspect<1,>=0.4.0 from https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl.metadata
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->ragstack-ai)
#   Obtaining dependency information for jsonpointer>=1.9 from https://files.pythonhosted.org/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl.metadata
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting tqdm (from openai<1,>=0->ragstack-ai)
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 994.4 kB/s eta 0:00:00 0:00:01
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->ragstack-ai)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.3 (from pydantic<3,>=1->ragstack-ai)
#   Obtaining dependency information for pydantic-core==2.14.3 from https://files.pythonhosted.org/packages/43/f1/bb0d58e0a545ec66deed44221b60892481a66834356787f5b2a086eca4d8/pydantic_core-2.14.3-cp311-cp311-macosx_10_7_x86_64.whl.metadata
#   Downloading pydantic_core-2.14.3-cp311-cp311-macosx_10_7_x86_64.whl.metadata (6.5 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic<3,>=1->ragstack-ai)
#   Obtaining dependency information for typing-extensions>=4.6.1 from https://files.pythonhosted.org/packages/24/21/7d397a4b7934ff4028987914ac1044d3b7d52712f30e2ac7a2ae5bc86dd0/typing_extensions-4.8.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->ragstack-ai)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/96/94/c31f58c7a7f470d5665935262ebd7455c7e4c7782eb525658d3dbf4b9403/urllib3-2.1.0-py3-none-any.whl.metadata
#   Downloading urllib3-2.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->ragstack-ai)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->ragstack-ai)
#   Obtaining dependency information for greenlet!=0.4.17 from https://files.pythonhosted.org/packages/3b/20/da6746e1efbb114740b6e1671ee0d35a5ff39e49f6a1c169e8328d47b7c8/greenlet-3.0.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading greenlet-3.0.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.7 kB)
# Collecting regex>=2022.1.18 (from tiktoken<0.6.0,>=0.3.2->ragstack-ai)
#   Obtaining dependency information for regex>=2022.1.18 from https://files.pythonhosted.org/packages/27/b8/fde0e99442b328d159bd0b2c0ff5401e1f1839e7a8d7339308b3915c7faa/regex-2023.10.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading regex-2023.10.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 871.5 kB/s eta 0:00:00 0:00:01
# Collecting cassandra-driver>=3.28.0 (from cassio~=0.1.3->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for cassandra-driver>=3.28.0 from https://files.pythonhosted.org/packages/5e/35/b51a06a371e8a538a63918049ebde4ade30c00c3ea6d7b1fa4556e9b23e4/cassandra_driver-3.28.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading cassandra_driver-3.28.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.4 (from faker~=19.11.0->astrapy==0.5.8->ragstack-ai)
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->ragstack-ai) (23.2)
# Collecting cfgv>=2.0.0 (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for cfgv>=2.0.0 from https://files.pythonhosted.org/packages/c5/55/51844dd50c4fc7a33b653bfaba4c2456f06955289ca770a5dbd5fd267374/cfgv-3.4.0-py2.py3-none-any.whl.metadata
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for identify>=1.0.0 from https://files.pythonhosted.org/packages/46/02/2581c37256119d65e6f1f47b62dd51dd3136d6b207bb49a8885a0d45c41a/identify-2.5.31-py2.py3-none-any.whl.metadata
#   Downloading identify-2.5.31-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for nodeenv>=0.11.1 from https://files.pythonhosted.org/packages/1a/e6/6d2ead760a9ddb35e65740fd5a57e46aadd7b0c49861ab24f94812797a1c/nodeenv-1.8.0-py2.py3-none-any.whl.metadata
#   Downloading nodeenv-1.8.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for virtualenv>=20.10.0 from https://files.pythonhosted.org/packages/7f/19/1f0eddcb9acf00a95793ce83417f69e0fd106c192121360af499cd6fde39/virtualenv-20.24.6-py3-none-any.whl.metadata
#   Downloading virtualenv-20.24.6-py3-none-any.whl.metadata (4.5 kB)
# Collecting iniconfig (from pytest~=7.4.2->astrapy==0.5.8->ragstack-ai)
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest~=7.4.2->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for pluggy<2.0,>=0.12 from https://files.pythonhosted.org/packages/05/b8/42ed91898d4784546c5f06c60506400548db3f7a4b3fb441cba4e5c17952/pluggy-1.3.0-py3-none-any.whl.metadata
#   Downloading pluggy-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting coverage[toml]>=5.2.1 (from pytest-cov~=4.1.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for coverage[toml]>=5.2.1 from https://files.pythonhosted.org/packages/a9/6b/4d3b9ce8b79378f960e3b74bea4569daf6bd3e1d562a15c9ce4d40be182c/coverage-7.3.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading coverage-7.3.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.1 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->ragstack-ai)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting six>=1.9 (from cassandra-driver>=3.28.0->cassio~=0.1.3->astrapy==0.5.8->ragstack-ai)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting geomet<0.3,>=0.1 (from cassandra-driver>=3.28.0->cassio~=0.1.3->astrapy==0.5.8->ragstack-ai)
#   Using cached geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from nodeenv>=0.11.1->pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (68.2.2)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for distlib<1,>=0.3.7 from https://files.pythonhosted.org/packages/43/a0/9ba967fdbd55293bacfc1507f58e316f740a3b231fc00e3d86dc39bc185a/distlib-0.3.7-py2.py3-none-any.whl.metadata
#   Using cached distlib-0.3.7-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting filelock<4,>=3.12.2 (from virtualenv>=20.10.0->pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for filelock<4,>=3.12.2 from https://files.pythonhosted.org/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl.metadata
#   Downloading filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting platformdirs<4,>=3.9.1 (from virtualenv>=20.10.0->pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for platformdirs<4,>=3.9.1 from https://files.pythonhosted.org/packages/56/29/3ec311dc18804409ecf0d2b09caa976f3ae6215559306b5b530004e11156/platformdirs-3.11.0-py3-none-any.whl.metadata
#   Downloading platformdirs-3.11.0-py3-none-any.whl.metadata (11 kB)
# Collecting click (from geomet<0.3,>=0.1->cassandra-driver>=3.28.0->cassio~=0.1.3->astrapy==0.5.8->ragstack-ai)
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Downloading ragstack_ai-0.1.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.2 MB/s eta 0:00:0000:0100:01
# Downloading astrapy-0.5.8-py3-none-any.whl (18 kB)
# Using cached aiohttp-3.8.6-cp311-cp311-macosx_10_9_x86_64.whl (365 kB)
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Downloading dataclasses_json-0.6.2-py3-none-any.whl (28 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading numpy-1.26.2-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading openai-0.28.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic-2.5.1-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.6/381.6 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_core-2.14.3-cp311-cp311-macosx_10_7_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.9 MB/s eta 0:00:0000:0100:01
# Downloading pytest_subtests-0.11.0-py3-none-any.whl (6.7 kB)
# Using cached PyYAML-6.0.1-cp311-cp311-macosx_10_9_x86_64.whl (187 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached SQLAlchemy-2.0.23-cp311-cp311-macosx_10_9_x86_64.whl (2.1 MB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading tiktoken-0.5.1-cp311-cp311-macosx_10_9_x86_64.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.5/953.5 kB 2.9 MB/s eta 0:00:0000:0100:01
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading cassio-0.1.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 551.8 kB/s eta 0:00:000:00:01
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_10_9_x86_64.whl (121 kB)
# Downloading Faker-19.11.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.2 MB/s eta 0:00:0000:0100:01
# Using cached frozenlist-1.4.0-cp311-cp311-macosx_10_9_x86_64.whl (47 kB)
# Using cached greenlet-3.0.1-cp311-cp311-macosx_10_9_universal2.whl (263 kB)
# Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Using cached marshmallow-3.20.1-py3-none-any.whl (49 kB)
# Downloading pre_commit-3.5.0-py2.py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Downloading pytest-7.4.3-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.1/325.1 kB 2.6 MB/s eta 0:00:0000:0100:01
# Downloading pytest_cov-4.1.0-py3-none-any.whl (21 kB)
# Downloading pytest_testdox-3.1.0-py2.py3-none-any.whl (9.0 kB)
# Downloading regex-2023.10.3-cp311-cp311-macosx_10_9_x86_64.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading urllib3-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 3.3 MB/s eta 0:00:00
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Downloading cassandra_driver-3.28.0-cp311-cp311-macosx_10_9_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 3.2 MB/s eta 0:00:0000:0100:01
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading identify-2.5.31-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading nodeenv-1.8.0-py2.py3-none-any.whl (22 kB)
# Using cached pluggy-1.3.0-py3-none-any.whl (18 kB)
# Using cached virtualenv-20.24.6-py3-none-any.whl (3.8 MB)
# Using cached distlib-0.3.7-py2.py3-none-any.whl (468 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached platformdirs-3.11.0-py3-none-any.whl (17 kB)
# Downloading coverage-7.3.2-cp311-cp311-macosx_10_9_x86_64.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.0/200.0 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# Installing collected packages: distlib, urllib3, typing-extensions, tqdm, tenacity, sniffio, six, regex, PyYAML, python-dotenv, pluggy, platformdirs, numpy, nodeenv, mypy-extensions, multidict, marshmallow, jsonpointer, iniconfig, idna, identify, greenlet, frozenlist, filelock, coverage, click, charset-normalizer, cfgv, certifi, attrs, async-timeout, annotated-types, yarl, virtualenv, typing-inspect, SQLAlchemy, requests, python-dateutil, pytest, pydantic-core, jsonpatch, geomet, anyio, aiosignal, tiktoken, requests-toolbelt, pytest-testdox, pytest-subtests, pytest-cov, pydantic, pre-commit, faker, dataclasses-json, cassandra-driver, aiohttp, openai, cassio, astrapy, ragstack-ai
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/argcomplete-0.0.0.dist-info due to invalid metadata entry 'name'
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.23 aiohttp-3.8.6 aiosignal-1.3.1 annotated-types-0.6.0 anyio-3.7.1 astrapy-0.5.8 async-timeout-4.0.3 attrs-23.1.0 cassandra-driver-3.28.0 cassio-0.1.3 certifi-2023.7.22 cfgv-3.4.0 charset-normalizer-3.3.2 click-8.1.7 coverage-7.3.2 dataclasses-json-0.6.2 distlib-0.3.7 faker-19.11.1 filelock-3.13.1 frozenlist-1.4.0 geomet-0.2.1.post1 greenlet-3.0.1 identify-2.5.31 idna-3.4 iniconfig-2.0.0 jsonpatch-1.33 jsonpointer-2.4 marshmallow-3.20.1 multidict-6.0.4 mypy-extensions-1.0.0 nodeenv-1.8.0 numpy-1.26.2 openai-0.28.1 platformdirs-3.11.0 pluggy-1.3.0 pre-commit-3.5.0 pydantic-2.5.1 pydantic-core-2.14.3 pytest-7.4.3 pytest-cov-4.1.0 pytest-subtests-0.11.0 pytest-testdox-3.1.0 python-dateutil-2.8.2 python-dotenv-1.0.0 ragstack-ai-0.1.0 regex-2023.10.3 requests-2.31.0 requests-toolbelt-1.0.0 six-1.16.0 sniffio-1.3.0 tenacity-8.2.3 tiktoken-0.5.1 tqdm-4.66.1 typing-extensions-4.8.0 typing-inspect-0.9.0 urllib3-2.1.0 virtualenv-20.24.6 yarl-1.9.2
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
import getpass
astra_token = getpass.getpass("Astra token:")
astra_endpoint = getpass.getpass("Astra db endpoint:")
openai_key = getpass.getpass("OpenAI Key:")
collection = input("Collection name:")

from langchain.vectorstores.astradb import AstraDB 
from langchain.embeddings import OpenAIEmbeddings

embedding = OpenAIEmbeddings(openai_api_key=openai_key)
vector_db = AstraDB(
        collection_name=collection,
        embedding=embedding,
        token=astra_token,
        api_endpoint=astra_endpoint
    )
print("Astra configured")

# %%
import csv
import requests

texts = []
metadatas = []
ids = []

url = 'http...'
r = requests.get(url)
text = r.iter_lines()

csv_reader = csv.DictReader(text, delimiter=';', quotechar='"')
for i, row in enumerate(csv_reader):
    texts.append(row["DESCRIPTION"])
    metadatas.append(row)
    ids.append(i)
vector_db.add_texts(texts, metadatas, ids=ids)

# %%
print(vector_db.astra_db.collection(collection).find())
